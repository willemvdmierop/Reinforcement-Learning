# %%
# !unzip /content/custom_gym.zip
# !pip install -e /content/custom_gym
# Out:
# Archive:  /content/custom_gym.zip
#    creating: custom_gym/
#   inflating: custom_gym/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/custom_gym/
#   inflating: __MACOSX/custom_gym/._.DS_Store
#    creating: custom_gym/custom_env.egg-info/
#   inflating: custom_gym/custom_env.egg-info/PKG-INFO
#   inflating: custom_gym/custom_env.egg-info/SOURCES.txt
#   inflating: custom_gym/custom_env.egg-info/requires.txt
#   inflating: custom_gym/custom_env.egg-info/top_level.txt
#   inflating: custom_gym/custom_env.egg-info/dependency_links.txt
#    creating: __MACOSX/custom_gym/custom_env.egg-info/
#   inflating: __MACOSX/custom_gym/custom_env.egg-info/._dependency_links.txt
#   inflating: custom_gym/setup.py
#   inflating: __MACOSX/custom_gym/._setup.py
#    creating: custom_gym/envs/
#   inflating: custom_gym/envs/.DS_Store
#    creating: __MACOSX/custom_gym/envs/
#   inflating: __MACOSX/custom_gym/envs/._.DS_Store
#    creating: custom_gym/envs/nymaze1_gym/
# ...

# %%
import gym
import custom_gym
